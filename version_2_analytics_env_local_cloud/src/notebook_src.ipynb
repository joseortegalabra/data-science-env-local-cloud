# %% [markdown]
# ### SEE VERSIONS OF PACKAGES

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.0.3

# %%
# a ver cómo anda el notebook src ahora desde visual studio code el container
# NO PUEDO HACER QUE ME LEA DESDE EL VISUAL STUDIO CODE :/

# %%
import mlflow
print(mlflow.__version__)
# Out:
# 2.3.0

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.23.5

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.11.3

# %%
# import tensorflow as tf

# %%
import matplotlib.pyplot as plt
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.8.0

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.12.2

# %%
import gcsfs
print(gcsfs.__version__)
# Out:
# 2023.9.2

# %%
#### VERTEX
from google.cloud import aiplatform
print(aiplatform.__version__)
# Out:
# 1.35.0

# %%
import docutils
print(docutils.__version__)
# Out:
# 0.20.1

# %%
import flask
print(flask.__version__)
# Out:
# 2.3.3

# %%
import statsmodels
print(statsmodels.__version__)
# Out:
# 0.14.1

# %%
import openpyxl
print(openpyxl.__version__)
# Out:
# 3.1.2

# %%
import joblib
print(joblib.__version__)
# Out:
# 1.3.2

# %%
# import kaleido
# print(kaleido.__version__)

# %% [markdown]
# ### TRY LOAD TRANSVERSAL FUNCTIONS

# %% [markdown]
# Read transversal functions since the root path of the image

# %%
# read thinking all the codes are executed from root
# from transversal import api
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # read thinking all the codes are executed from root
# ----> 2 from transversal import api
#
# ModuleNotFoundError: No module named 'transversal'

# %% [markdown]
# Change the located to stay in the root of the repo

# %%
import os
# fix root path to save outputs
actual_path = os.path.abspath(os.getcwd())
list_root_path = actual_path.split('/')[:-1]
root_path = '/'.join(list_root_path)
os.chdir(root_path)
print('root path: ', root_path)
# Out:
# root path:  /app

# %%
root_path
# Out:
# '/app'

# %%
from transversal import api

# %%
# call function of the script
api.print_hello_world()
# Out:
# hello world
